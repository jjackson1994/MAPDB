# %% [markdown]
# # RDBMS - MySQL
#
# ## 00 - Introduction
#
# Among the Relational DBMSs, the most widely known are Oracle, SQLite, Postgress, MariaDB, MySQL.
#
# Each one of them is characterized by a different set of "variations" on top of the base SQL language, although usually minor.
#
# We will use **MySQL** to run exercises about Relational DB transactions using the SQL language, as it is *today* at the top of the list of most widely used RDBs.
#
# https://db-engines.com/en/ranking_trend/relational+dbms
#
# https://www.statista.com/statistics/809750/worldwide-popularity-ranking-database-management-systems/
#
# https://insights.stackoverflow.com/survey/2021#most-popular-technologies-database

# %% [markdown]
# #### iPython magic
#
# An alternative way to perform queries from Python over a Jupyter-notebook is by using some notebook "magic", based on iPython and SQLAlchemy.
#
# This is a similar thing to what is usually done to load inline a figure from matplotlib (the `%matplotlib inline` thingy).
#
# To instruct iPython to interpret SQL commands, and to connect to the proper DB we have to:
# 1. load the extension for SQL language
# 2. set the environment variable to point to the connection to the DB

# %%
# %load_ext sql
# %env DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# env: DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db

# %% [markdown]
# Now, the notebooks cells can perform SQL transactions directly in plain SQL, by starting the cell with `%%sql`.
#
# By default, the result is also printed with the `pretty` pandas-like format.

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 7 rows affected.
# [('IMDb',),
#  ('information_schema',),
#  ('my_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('world',)]

# %% [markdown]
# An additional benefit is that a single `%slq` (not a double `%%sql`) can be used to join a SQL query with any Python command

# %%
my_python_var = %sql SHOW DATABASES
print(my_python_var)
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# | information_schema |
# |       my_db        |
# |       mysql        |
# | performance_schema |
# |        sys         |
# |       world        |
# +--------------------+

# %% [markdown]
# The combination of either of the two pythonic methods can be used to easily redirect the output of DB transactions to exploit all other well-known python modules, e.g. plotting with matplotlib

# %% [markdown]
# Check if a DB named `my_db` exist, and if not, create one.
# Then, switch to the new DB to start using it.

# %%
# %%sql
# CREATE DATABASE IF NOT EXISTS world;
# SHOW DATABASES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 6 rows affected.
# [('information_schema',),
#  ('my_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('world',)]

# %% [markdown]
# ## 05 Queries on well-formed DBs
#
# In MySQL we can load entire DBs from external files.
#
# The files will contain the full DB structure (tables and constraints) and will populate all tables with all records
#
# To load a DB into the MySQL server from the interactive docker shell, we can simply do the following:
#
# 1. Create a new DB named `world`
# 2. Import the content of the file `/opt/workspace/dbs/world.sql` into the newly created DB via
#
# ```bash
# $ mysql -u root -p world < /opt/workspace/dbs/world.sql
# ```
#
# _NB_: The `opt/workspace` directory has been defined as a Docker Volume, and is a shared location with your computer...

# %% [markdown]
# Using the `world` DB, perform queries to answer the folliwing questions.
#
# Additional references can be found here https://dev.mysql.com/doc/world-setup/en/
#
#
# Use a single query to answer the questions
#
# 1. Which country has the largest population?
# 2. Get the total number of cities in Canada.
# 3. Select the country with the most cities.
# 4. List all the languages spoken in the Southeast Asia region.
# 5. Identify the 5 most spoken language by number of countries.
# 6. What is the total population of the cities in the Caribbean region?
# 7. What Countries have a City named "Kingston"?
# 8. Plot the population density by country, limiting to the 25 with least density.
# 9. Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with highest GNP.
# 10. Create a scatter plot of the life expentency vs the GNP of all countries that have Spanish as their Official language.
#
#
# Suggestions:
# - Start by inspecting the DB tables structure
# - When in doubt, check the table content by selecting a few lines (use `LIMIT` to avoid returining all records)
# - Before finalizing the query, you can always perform "intermediate" queries to check if complex operations (groupby and join mostly) are stated correctly

# %%
# %%sql
# USE world;
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 3 rows affected.
# [('city',), ('country',), ('countrylanguage',)]

# %%
# %%sql
# SELECT * FROM city LIMIT 5;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Kabul', 'AFG', 'Kabol', 1780000),
#  (2, 'Qandahar', 'AFG', 'Qandahar', 237500),
#  (3, 'Herat', 'AFG', 'Herat', 186800),
#  (4, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800),
#  (5, 'Amsterdam', 'NLD', 'Noord-Holland', 731200)]

# %%
# %%sql
# SELECT * FROM country LIMIT 6;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('ABW', 'Aruba', 'North America', 'Caribbean', Decimal('193.00'), None, 103000, Decimal('78.4'), Decimal('828.00'), Decimal('793.00'), 'Aruba', 'Nonmetropolitan Territory of The Netherlands', 'Beatrix', 129, 'AW'),
#  ('AFG', 'Afghanistan', 'Asia', 'Southern and Central Asia', Decimal('652090.00'), 1919, 22720000, Decimal('45.9'), Decimal('5976.00'), None, 'Afganistan/Afqanestan', 'Islamic Emirate', 'Mohammad Omar', 1, 'AF'),
#  ('AGO', 'Angola', 'Africa', 'Central Africa', Decimal('1246700.00'), 1975, 12878000, Decimal('38.3'), Decimal('6648.00'), Decimal('7984.00'), 'Angola', 'Republic', 'José Eduardo dos Santos', 56, 'AO'),
#  ('AIA', 'Anguilla', 'North America', 'Caribbean', Decimal('96.00'), None, 8000, Decimal('76.1'), Decimal('63.20'), None, 'Anguilla', 'Dependent Territory of the UK', 'Elisabeth II', 62, 'AI'),
#  ('ALB', 'Albania', 'Europe', 'Southern Europe', Decimal('28748.00'), 1912, 3401200, Decimal('71.6'), Decimal('3205.00'), Decimal('2500.00'), 'Shqipëria', 'Republic', 'Rexhep Mejdani', 34, 'AL'),
#  ('AND', 'Andorra', 'Europe', 'Southern Europe', Decimal('468.00'), 1278, 78000, Decimal('83.5'), Decimal('1630.00'), None, 'Andorra', 'Parliamentary Coprincipality', '', 55, 'AD')]

# %%
# %%sql
# SELECT * FROM countrylanguage LIMIT 6;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('ABW', 'Dutch', 'T', Decimal('5.3')),
#  ('ABW', 'English', 'F', Decimal('9.5')),
#  ('ABW', 'Papiamento', 'F', Decimal('76.7')),
#  ('ABW', 'Spanish', 'F', Decimal('7.4')),
#  ('AFG', 'Balochi', 'F', Decimal('0.9')),
#  ('AFG', 'Dari', 'T', Decimal('32.1'))]

# %% [markdown]
# #### 1 - Which country has the largest population?

# %%
# %%sql
# SELECT Name, Population FROM country
# ORDER BY Population DESC LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('China', 1277558000)]

# %% [markdown]
# #### 2 - Get the total number of cities in Canada.

# %%
# %%sql
# SELECT COUNT(Name) AS CityCAN
# FROM city
# WHERE CountryCode= "CAN";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(49,)]

# %% [markdown]
# #### 3 - Select the country with the most cities.

# %%
# %%sql
# SELECT CountryCode, COUNT(Name) AS NumCitys
# FROM city
# GROUP BY CountryCode
# ORDER BY COUNT(Name) DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('CHN', 363)]

# %% [markdown]
# #### 4 - List all the languages spoken in the 'Southeast Asia' region.

# %%
# %%sql
#
# SELECT Region, COUNT(1)
# FROM country
# WHERE Region LIKE "%Asia"
# GROUP BY Region;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('Southern and Central Asia', 14),
#  ('Southeast Asia', 11),
#  ('Eastern Asia', 8)]

# %% [markdown]
# My function

# %%
# %%sql
# SELECT DISTINCT countrylanguage.Language
# FROM countrylanguage, country
# WHERE countrylanguage.CountryCode = country.Code
# AND Region = "Southeast Asia"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 47 rows affected.
# [('Chinese',),
#  ('English',),
#  ('Malay',),
#  ('Malay-English',),
#  ('Bali',),
#  ('Banja',),
#  ('Batakki',),
#  ('Bugi',),
#  ('Javanese',),
#  ('Madura',),
#  ('Minangkabau',),
#  ('Sunda',),
#  ('Khmer',),
#  ('Tšam',),
#  ('Vietnamese',),
#  ('Lao',),
#  ('Lao-Soung',),
#  ('Mon-khmer',),
#  ('Thai',),
#  ('Burmese',),
#  ('Chin',),
#  ('Kachin',),
#  ('Karen',),
#  ('Kayah',),
#  ('Mon',),
#  ('Rakhine',),
#  ('Shan',),
#  ('Dusun',),
#  ('Iban',),
#  ('Tamil',),
#  ('Bicol',),
#  ('Cebuano',),
#  ('Hiligaynon',),
#  ('Ilocano',),
#  ('Maguindanao',),
#  ('Maranao',),
#  ('Pampango',),
#  ('Pangasinan',),
#  ('Pilipino',),
#  ('Waray-waray',),
#  ('Kuy',),
#  ('Portuguese',),
#  ('Man',),
#  ('Miao',),
#  ('Muong',),
#  ('Nung',),
#  ('Tho',)]

# %%
# %%sql
#
# SELECT DISTINCT countrylanguage.Language
# FROM country
# INNER JOIN countrylanguage ON country.Code =  countrylanguage.CountryCode
# WHERE Region = "Southeast Asia";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 47 rows affected.
# [('Chinese',),
#  ('English',),
#  ('Malay',),
#  ('Malay-English',),
#  ('Bali',),
#  ('Banja',),
#  ('Batakki',),
#  ('Bugi',),
#  ('Javanese',),
#  ('Madura',),
#  ('Minangkabau',),
#  ('Sunda',),
#  ('Khmer',),
#  ('Tšam',),
#  ('Vietnamese',),
#  ('Lao',),
#  ('Lao-Soung',),
#  ('Mon-khmer',),
#  ('Thai',),
#  ('Burmese',),
#  ('Chin',),
#  ('Kachin',),
#  ('Karen',),
#  ('Kayah',),
#  ('Mon',),
#  ('Rakhine',),
#  ('Shan',),
#  ('Dusun',),
#  ('Iban',),
#  ('Tamil',),
#  ('Bicol',),
#  ('Cebuano',),
#  ('Hiligaynon',),
#  ('Ilocano',),
#  ('Maguindanao',),
#  ('Maranao',),
#  ('Pampango',),
#  ('Pangasinan',),
#  ('Pilipino',),
#  ('Waray-waray',),
#  ('Kuy',),
#  ('Portuguese',),
#  ('Man',),
#  ('Miao',),
#  ('Muong',),
#  ('Nung',),
#  ('Tho',)]

# %% [markdown]
# #### 5 - Identify the 5 **most** spoken language by number of countries.

# %% [markdown]
# Identifying the most or least requires doing a count and a sort.
# The table already has one row per country so any count is already a count of countries

# %%
# %%sql
#
# SELECT Language, COUNT(Language) AS count
# FROM countrylanguage
# GROUP BY Language
# ORDER BY COUNT(Language) DESC
# LIMIT 5;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('English', 60),
#  ('Arabic', 33),
#  ('Spanish', 28),
#  ('French', 25),
#  ('German', 19)]

# %% [markdown]
# #### 6 - What is the total population of the cities in the Caribbean region?

# %%
# %%sql
#
# SELECT SUM(Population)
# FROM country
# WHERE Region LIKE "Caribb%";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(Decimal('38140000'),)]

# %% [markdown]
# #### 7 - What Countries have a City named "Kingston"?

# %%
# %%sql
#
# SELECT CountryCode, Name
# FROM city
# WHERE Name LIKE "Kings%";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('GBR', 'Kingston upon Hull'),
#  ('JAM', 'Kingston'),
#  ('NFK', 'Kingston'),
#  ('VCT', 'Kingstown')]

# %%
# %%sql
# SELECT country.Name,  city.Name AS CityName
# FROM country
# INNER JOIN city ON country.Code=city.CountryCode
# WHERE city.Name LIKE "Kings%";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('United Kingdom', 'Kingston upon Hull'),
#  ('Jamaica', 'Kingston'),
#  ('Norfolk Island', 'Kingston'),
#  ('Saint Vincent and the Grenadines', 'Kingstown')]

# %% [markdown]
# #### 8 - Plot the population density by country, limiting to the 25 with least density.

# %%
# %%sql
# SELECT Name, Population/SurfaceArea AS PopDensity
# FROM country
# ORDER BY PopDensity ASC
# LIMIT 25;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# [('United States Minor Outlying Islands', Decimal('0.0000')),
#  ('British Indian Ocean Territory', Decimal('0.0000')),
#  ('Heard Island and McDonald Islands', Decimal('0.0000')),
#  ('South Georgia and the South Sandwich Islands', Decimal('0.0000')),
#  ('Bouvet Island', Decimal('0.0000')),
#  ('French Southern territories', Decimal('0.0000')),
#  ('Antarctica', Decimal('0.0000')),
#  ('Greenland', Decimal('0.0259')),
#  ('Svalbard and Jan Mayen', Decimal('0.0513')),
#  ('Falkland Islands', Decimal('0.1643')),
#  ('Pitcairn', Decimal('1.0204')),
#  ('Western Sahara', Decimal('1.1015')),
#  ('Mongolia', Decimal('1.6993')),
#  ('French Guiana', Decimal('2.0111')),
#  ('Namibia', Decimal('2.0939')),
#  ('Australia', Decimal('2.4397')),
#  ('Suriname', Decimal('2.5541')),
#  ('Mauritania', Decimal('2.6036')),
#  ('Iceland', Decimal('2.7087')),
#  ('Botswana', Decimal('2.7882')),
#  ('Canada', Decimal('3.1239')),
#  ('Libyan Arab Jamahiriya', Decimal('3.1855')),
#  ('Guyana', Decimal('4.0052')),
#  ('Gabon', Decimal('4.5803')),
#  ('Central African Republic', Decimal('5.8027'))]

# %% [markdown]
# #### 9 - Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with highest GNP.
#
# Very similar too the type in the exam

# %%
# %%sql
#
# SELECT  Name, GNP
# FROM country
# WHERE IndepYear > 1849
# AND IndepYear < 1910
# ORDER BY GNP DESC
# LIMIT 10;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Italy', Decimal('1161755.00')),
#  ('Canada', Decimal('598862.00')),
#  ('Australia', Decimal('351182.00')),
#  ('Iran', Decimal('195746.00')),
#  ('Norway', Decimal('145895.00')),
#  ('New Zealand', Decimal('54669.00')),
#  ('Romania', Decimal('38158.00')),
#  ('Cuba', Decimal('17843.00')),
#  ('Luxembourg', Decimal('16321.00')),
#  ('Bulgaria', Decimal('12178.00'))]

# %%
SELECT  Col, Col2
FROM country
WHERE Col4 > 1849
AND Col4 < 1910
ORDER BY Col2 DESC
LIMIT 10;

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# city, countrylanguage, country

# %% [markdown]
# #### 10 - Create a scatter plot of the life expentency vs the GNP of all countries that have Spanish as their Official language.

# %%
# %%sql
# SELECT country.LifeExpectancy, country.GNP, country.Name
# FROM country
# INNER JOIN countrylanguage ON countrylanguage.CountryCode = country.Code
# WHERE countrylanguage.Language = 'Spanish'
# ORDER BY country.LifeExpectancy DESC
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'IMDb.country' doesn't exist
# [SQL: SELECT country.LifeExpectancy, country.GNP, country.Name
# FROM country
# INNER JOIN countrylanguage ON countrylanguage.CountryCode = country.Code
# WHERE countrylanguage.Language = 'Spanish'
# ORDER BY country.LifeExpectancy DESC]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ## 06 More on queries

# %% [markdown]
# Let' import a well-structured DB, with several tables and relationships, to be used as a sandbox for further exercises on queries.
#
# The `.sql` file can be found at: `/opt/workspace/dbs/IMDb_pruned.sql`.
#
# The DB is freely available and is taken from the IMDb (Internet Movie Database) website (https://www.imdb.com/interfaces/).
#
# The entire database is composed of a dozen of tables, hosing all people involved in Movies, Shorts, TV Show Epidoses and more since the 1890s.
#
# To simplify the execution of queries, we will work with a slimmed-down version of the entire DB, with still plenty of records for us to extract interesting information.

# %% [markdown]
# 1. Create a new DB named `IMDb`
# 2. Import the content of the file `/opt/workspace/dbs/IMDb_pruned.sql` into the newly created DB
# (this might take a minute or two...)

# %%
from sqlalchemy_schemadisplay import create_schema_graph
from sqlalchemy import MetaData

graph = create_schema_graph(metadata=MetaData('postgres:/opt/workspace/dbs/IMDb_pruned.sql'))
graph.write_png('IMDb.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [141], in <cell line: 1>()
# ----> 1 from sqlalchemy_schemadisplay import create_schema_graph
#       2 from sqlalchemy import MetaData
#       4 graph = create_schema_graph(metadata=MetaData('postgres:/opt/workspace/dbs/IMDb_pruned.sql'))
#
# ModuleNotFoundError: No module named 'sqlalchemy_schemadisplay'

# %%
# %%sql
# CREATE DATABASE IF NOT EXISTS IMDb;
# SHOW DATABASES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 7 rows affected.
# [('IMDb',),
#  ('information_schema',),
#  ('my_db',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('world',)]

# %% [markdown]
# ### Check which tables are available

# %%
# %%sql
# USE IMDb;
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 7 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',)]

# %% [markdown]
# ### Describe the content of table Names_

# %%
# %%sql
# DESCRIBE Names_
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', b'varchar(255)', 'NO', '', None, ''),
#  ('name_', b'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', b'smallint', 'YES', '', None, ''),
#  ('death_year', b'smallint', 'YES', '', None, '')]

# %% [markdown]
# ### People by birth year
#
# A) Start by limiting the query to 1000 entries
#
# 1. Draw an histogram of the year of birth
# 2. Draw a second histogram with the year of birth of the 1000 youngest people in the list

# %%
# %%sql
#
# SELECT birth_year, COUNT(birth_year) AS Count
# FROM Names_
# GROUP BY birth_year
# LIMIT 1000;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 142 rows affected.
# [(1924, 593),
#  (1934, 908),
#  (1918, 287),
#  (1922, 539),
#  (1916, 226),
#  (1925, 633),
#  (1901, 26),
#  (1920, 440),
#  (1917, 267),
#  (1904, 45),
#  (1914, 199),
#  (1954, 1796),
#  (1929, 827),
#  (1907, 83),
#  (1923, 559),
#  (1953, 1761),
#  (1912, 179),
#  (1928, 791),
#  (1910, 112),
#  (1913, 135),
#  (1915, 192),
#  (1921, 438),
#  (1908, 107),
#  (1932, 852),
#  (1940, 1301),
#  (1965, 2771),
#  (1950, 1755),
#  (1930, 921),
#  (1939, 1245),
#  (1963, 2631),
#  (1935, 999),
#  (1968, 2815),
#  (1967, 2707),
#  (1969, 2986),
#  (1955, 1906),
#  (1952, 1738),
#  (1958, 2110),
#  (1974, 3258),
#  (1960, 2255),
#  (1945, 1524),
#  (1975, 3273),
#  (1959, 2158),
#  (1962, 2559),
#  (1964, 2734),
#  (1957, 2105),
#  (1973, 3168),
#  (1948, 1793),
#  (1961, 2354),
#  (1970, 3333),
#  (1966, 2666),
#  (1979, 3487),
#  (1956, 1899),
#  (1943, 1538),
#  (1972, 3241),
#  (1944, 1610),
#  (1942, 1439),
#  (1937, 1081),
#  (1949, 1750),
#  (1946, 1789),
#  (1947, 1952),
#  (1971, 3286),
#  (1981, 3344),
#  (1980, 3497),
#  (1976, 3273),
#  (1977, 3187),
#  (1951, 1695),
#  (1936, 1029),
#  (1941, 1354),
#  (1933, 915),
#  (1982, 3309),
#  (1926, 662),
#  (1931, 898),
#  (1927, 729),
#  (1938, 1127),
#  (1919, 331),
#  (1906, 64),
#  (1897, 6),
#  (1909, 101),
#  (1900, 24),
#  (1903, 35),
#  (1905, 52),
#  (1986, 2813),
#  (1893, 3),
#  (1978, 3452),
#  (1985, 2870),
#  (1983, 3088),
#  (1911, 123),
#  (1898, 17),
#  (1990, 2038),
#  (1988, 2369),
#  (1902, 33),
#  (1992, 1606),
#  (1987, 2509),
#  (1984, 3033),
#  (1989, 2209),
#  (1887, 1),
#  (1991, 1766),
#  (1995, 1033),
#  (1899, 18),
#  (1996, 855),
#  (1993, 1367),
#  (1894, 4),
#  (1876, 1),
#  (1998, 656),
#  (1896, 12),
#  (1994, 1205),
#  (1870, 1),
#  (1997, 782),
#  (1999, 503),
#  (1892, 3),
#  (2005, 162),
#  (2001, 374),
#  (2009, 58),
#  (2003, 219),
#  (2018, 5),
#  (2000, 414),
#  (2002, 278),
#  (2004, 215),
#  (2010, 38),
#  (2006, 120),
#  (2012, 23),
#  (2008, 80),
#  (2007, 107),
#  (2014, 11),
#  (2011, 32),
#  (2015, 5),
#  (2013, 11),
#  (1895, 4),
#  (1891, 3),
#  (1879, 2),
#  (2020, 2),
#  (2017, 2),
#  (2019, 1),
#  (2021, 1),
#  (2016, 1),
#  (1873, 1),
#  (13, 1),
#  (1889, 1),
#  (1890, 3),
#  (1886, 1),
#  (1878, 1),
#  (1088, 1)]

# %%
# %%sql
#
# SELECT name_, birth_year
# FROM Names_
# ORDER BY birth_year DESC
# LIMIT 100;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 100 rows affected.
# [('Grace Warrior Irwin Powell', 2021),
#  ('Lilah Sykes', 2020),
#  ('Wilfred Johnson', 2020),
#  ('Archie Mountbatten-Windsor', 2019),
#  ('Ronin Willingham', 2018),
#  ('Stormi Webster', 2018),
#  ('Spencer Nestor', 2018),
#  ('Sebastian Joyce', 2018),
#  ('Prince Louis of Cambridge', 2018),
#  ('Jackson Roloff', 2017),
#  ('Gilbert', 2017),
#  ('Greyson Mathews', 2016),
#  ('Thea Eddey', 2015),
#  ('Charlie', 2015),
#  ('Holden Marzec', 2015),
#  ('Princess Charlotte of Cambridge', 2015),
#  ('Karen Øye', 2015),
#  ('Fox Messitt', 2014),
#  ('Maksim Ivanov', 2014),
#  ('Everly Carganilla', 2014),
#  ('Natalye Archiles', 2014),
#  ('Miriam Spumpkin', 2014),
#  ('Titus Milo Leon', 2014),
#  ('Dashiell Messitt', 2014),
#  ('Devyn McDowell', 2014),
#  ('Charlotte Britz', 2014),
#  ('Indiana Feek', 2014),
#  ('Reign Aston Disick', 2014),
#  ('Prince George of Cambridge', 2013),
#  ('Grayson Eddey', 2013),
#  ('Evfrosiniya Melnik', 2013),
#  ('Gaius Lee DuPree', 2013),
#  ('Halo Asada', 2013),
#  ('Ki Eun-Yoo', 2013),
#  ('Iván Renedo', 2013),
#  ('Eros Herrero', 2013),
#  ('Marcus Anthony Duggar', 2013),
#  ('Chace Elijah', 2013),
#  ('Cookie Sykes', 2013),
#  ('Vera Ostrovskaya', 2012),
#  ('Ilya Sintsov', 2012),
#  ('Everleigh McDonell', 2012),
#  ('Quinn Copeland', 2012),
#  ('Mykal-Michelle Harris', 2012),
#  ('Tenta Banka', 2012),
#  ('Eva Smirnova', 2012),
#  ('Grumpy Cat', 2012),
#  ('Hridyansh Shekhawat', 2012),
#  ('Mustafa Konak', 2012),
#  ('Sophia', 2012),
#  ('Roger Dale Floyd', 2012),
#  ('Indiana Arnold', 2012),
#  ('Arslan Krymchurin', 2012),
#  ('Makayla Rose Hilli', 2012),
#  ('Penelope Scotland Disick', 2012),
#  ('So-yi Park', 2012),
#  ('Alan S. Kim', 2012),
#  ('DeOrr Kunz Jr.', 2012),
#  ('Blue Ivy Carter', 2012),
#  ('Mikail Akar', 2012),
#  ('Merlín Atahualpa Mollo Oreiro', 2012),
#  ('Carina Battrick', 2012),
#  ('Park Da-Yeon', 2011),
#  ('Moroccan Cannon', 2011),
#  ('Iwo Rajski', 2011),
#  ('Lavinia Burat', 2011),
#  ('Ilan Debrabant', 2011),
#  ('Ravi Cabot-Conyers', 2011),
#  ('Lilou Siauvaud', 2011),
#  ('Michael James Duggar', 2011),
#  ('Lorena Queiroz', 2011),
#  ('Julian Hilliard', 2011),
#  ('Juliette Maxyme Proulx', 2011),
#  ('Anti', 2011),
#  ('Mariya Markhay', 2011),
#  ('Qianyi Ma', 2011),
#  ('Violet McGraw', 2011),
#  ('Michael Neyland', 2011),
#  ('Josefína Krycnerová', 2011),
#  ('Malea Emma Tjandrawidjaja', 2011),
#  ('Aura Stehle', 2011),
#  ('Diesel La Torraca', 2011),
#  ('Lea-Kim Lafrance-Leroux', 2011),
#  ('Maisie Sly', 2011),
#  ('Stanislav Solomatin', 2011),
#  ('Maya Le Clark', 2011),
#  ('Shiloh Bearman', 2011),
#  ('Kue Lawrence', 2011),
#  ("Ja'Siah Young", 2011),
#  ('Hyun-jun Jung', 2011),
#  ('Kurumi Inagaki', 2011),
#  ('Lil Bub', 2011),
#  ('Winx', 2011),
#  ('Ashwanth Ashokkumar', 2011),
#  ('Vitaliya Kornienko', 2010),
#  ('Ethan Thomas Jung', 2010),
#  ('Taiyô Saitô', 2010),
#  ('Nicholas Martorell Jr.', 2010),
#  ('Sonia Kasperek', 2010),
#  ('Alejandra Howard', 2010)]

# %% [markdown]
# #SELECT birth_year FROM Names_ ORDER BY birth_year DESC LIMIT 1000

# %%
# %%sql
# SELECT birth_year, COUNT(birth_year)
# FROM Names_
# GROUP BY birth_year
# ORDER BY birth_year DESC
# LIMIT  1000;
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '1000' at line 4
# [SQL: SELECT birth_year, COUNT(birth_year) FROM Names_
# GROUP BY birth_year
# ORDER BY birth_year DESC
# LIMIT birth_year 1000;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# B) Extend the query to all records in the table
#
# 1. Check for outliers (inspect min and max)
# 2. If any outlier is found, limit the query to a reasonable range (at least people born after 1850)
# 3. Draw a new histogram with the year of birth
# 4. Compute the mean and std of year of birth

# %%
# B.1

# %%
# B.2

# %%
# B.3

# %%
# B.4

# %% [markdown]
# ### Movie stats
#
# 1. Plot how many titles can be found in the DB per year, over the past 25 years
# 2. List the names of all actors who have had the role of Spider-Man and the corresponding Title
# 3. List and count the 10 people who appeared the most in movies by "Wes Anderson"
#
# ![image.png](attachment:image.png)

# %%
# %%sql
# DESCRIBE Names_;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', b'varchar(255)', 'NO', '', None, ''),
#  ('name_', b'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', b'smallint', 'YES', '', None, ''),
#  ('death_year', b'smallint', 'YES', '', None, '')]

# %%
# %%sql
# USE IMDb;
# SHOW TABLES;
# DESCRIBE Had_role;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 7 rows affected.
# 3 rows affected.
# [('title_id', b'varchar(255)', 'NO', '', None, ''),
#  ('name_id', b'varchar(255)', 'NO', '', None, ''),
#  ('role_', b'text', 'NO', '', None, '')]

# %%
# %%sql
# SELECT *
# FROM Had_role
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('tt0011216', 'nm0290157', b'Soledad'),
#  ('tt0011216', 'nm0869559', b'Migu\xc3\xa9lan'),
#  ('tt0011216', 'nm0595321', b'R\xc3\xa9al'),
#  ('tt0015724', 'nm0844752', b'Bruno'),
#  ('tt0015724', 'nm0869732', b'Sof\xc3\xada')]

# %% [markdown]
# #### 1 - Plot how many titles can be found in the DB per year, over the past 25 years

# %%
# %%sql
# SELECT start_year, COUNT(title_id) AS Films
# FROM Titles
# WHERE start_year < 2023
# GROUP BY start_year
# ORDER BY start_year DESC
# LIMIT 25;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# [(2022, 6211),
#  (2021, 51422),
#  (2020, 56755),
#  (2019, 61580),
#  (2018, 66211),
#  (2017, 65984),
#  (2016, 61554),
#  (2015, 55864),
#  (2014, 50654),
#  (2013, 46740),
#  (2012, 43170),
#  (2011, 39155),
#  (2010, 35706),
#  (2009, 34450),
#  (2008, 30564),
#  (2007, 27860),
#  (2006, 24898),
#  (2005, 22746),
#  (2004, 19711),
#  (2003, 18189),
#  (2002, 16937),
#  (2001, 16598),
#  (2000, 15677),
#  (1999, 16643),
#  (1998, 15749)]

# %% [markdown]
# #### 2 - List the names of all actors who have had the role of Spider-Man and the corresponding Title

# %% [markdown]
# ##NOT MINE

# %%
# %%sql
#
# SELECT DISTINCT Titles.primary_title
# FROM Titles
# WHERE (
#     Titles.title_id IN (
#         SELECT Had_role.title_id
#         FROM Had_role
#         WHERE (Had_role.role_ LIKE "Spider-Man")
#     )
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 348 rows affected.
# [(b'Spider-Man: The Animated Series',),
#  (b'Spider-Man',),
#  (b'Spider-Man Unlimited',),
#  (b'Spider-Man 2',),
#  (b'Spider-Man 3',),
#  (b'Cry Vulture',),
#  (b'Deadly Choices',),
#  (b'Destiny Unleashed',),
#  (b'Ill-Met by Moonlight',),
#  (b'Matters of the Heart',),
#  (b'One Is the Loneliest Number',),
#  (b'Sins of the Fathers',),
#  (b'Steel Cold Heart',),
#  (b'Sustenance',),
#  (b'Where Evil Nests',),
#  (b'Worlds Apart: Part 1',),
#  (b'Worlds Apart: Part 2',),
#  (b'Day of the Chameleon',),
#  (b'Doctor Octopus: Armed and Dangerous',),
#  (b'Kraven the Hunter',),
#  (b'Neogenic Nightmare Chapter 10: The Immortal Vampire',),
#  (b'Neogenic Nightmare Chapter 11: Tablet of Time',),
#  (b'Neogenic Nightmare Chapter 12: Ravages of Time',),
#  (b'Neogenic Nightmare Chapter 13: Shriek of the Vulture',),
#  (b'Neogenic Nightmare Chapter 14: The Final Nightmare',),
#  (b'Neogenic Nightmare Chapter 1: The Insidious Six',),
#  (b'Neogenic Nightmare Chapter 2: Battle of the Insidious Six',),
#  (b'Neogenic Nightmare Chapter 3: Hydro-Man',),
#  (b'Neogenic Nightmare Chapter 4: The Mutant Agenda',),
#  (b'Neogenic Nightmare Chapter 5: Mutants Revenge',),
#  (b'Neogenic Nightmare Chapter 6: Morbius',),
#  (b'Neogenic Nightmare Chapter 7: Enter the Punisher',),
#  (b'Neogenic Nightmare Chapter 8: Duel of the Hunters',),
#  (b'Neogenic Nightmare Chapter 9: Blade the Vampire Hunter',),
#  (b'Night of the Lizard',),
#  (b'Partners in Danger Chapter 10: Lizard King',),
#  (b'Partners in Danger Chapter 11: The Prowler',),
#  (b'Partners in Danger Chapter 1: Guilty',),
#  (b'Partners in Danger Chapter 2: The Cat',),
#  (b'Partners in Danger Chapter 3: The Black Cat',),
#  (b'Partners in Danger Chapter 4: Return of Kraven',),
#  (b'Partners in Danger Chapter 5: Partners',),
#  (b'Partners in Danger Chapter 6: The Awakening',),
#  (b'Partners in Danger Chapter 7: The Vampire Queen',),
#  (b'Partners in Danger Chapter 8: The Return of the Green Goblin',),
#  (b'Partners in Danger Chapter 9: The Haunting of Mary Jane',),
#  (b'Secret Wars, Chapter 1: Arrival',),
#  (b'Secret Wars, Chapter 2: The Gauntlet of the Red Skull',),
#  (b'Secret Wars, Chapter 3: Doom',),
#  (b'Sins of the Fathers Chapter 10: Venom Returns',),
#  (b'Sins of the Fathers Chapter 11: Carnage',),
#  (b'Sins of the Fathers Chapter 12: The Spot',),
#  (b'Sins of the Fathers Chapter 13: Goblin War!',),
#  (b'Sins of the Fathers Chapter 14: The Turning Point',),
#  (b'Sins of the Fathers Chapter 1: Doctor Strange',),
#  (b'Sins of the Fathers Chapter 2: Make a Wish',),
#  (b'Sins of the Fathers Chapter 3: Attack of the Octobot',),
#  (b'Sins of the Fathers Chapter 4: Enter the Green Goblin',),
#  (b'Sins of the Fathers Chapter 5: The Rocket Racer',),
#  (b'Sins of the Fathers Chapter 6: Framed',),
#  (b'Sins of the Fathers Chapter 7: The Man Without Fear',),
#  (b'Sins of the Fathers Chapter 8: The Ultimate Slayer',),
#  (b'Sins of the Fathers Chapter 9: Tombstone',),
#  (b'Six Forgotten Warriors Chapter 1',),
#  (b'Six Forgotten Warriors Chapter 2: Unclaimed Legacy',),
#  (b'Six Forgotten Warriors Chapter 3: Secrets of the Six',),
#  (b'Six Forgotten Warriors Chapter 4: The Six Fight Again',),
#  (b'Six Forgotten Warriors Chapter 5: The Price of Heroism',),
#  (b'Spider Wars, Chapter 1: I Really, Really Hate Clones',),
#  (b'Spider Wars, Chapter 2: Farewell Spider-Man',),
#  (b'The Alien Costume: Part 1',),
#  (b'The Alien Costume: Part 2',),
#  (b'The Alien Costume: Part 3',),
#  (b'The Hobgoblin: Part 1',),
#  (b'The Hobgoblin: Part 2',),
#  (b'The Menace of Mysterio',),
#  (b'The Return of Hydro-Man: Part 2',),
#  (b'The Return of the Spider-Slayers',),
#  (b'The Spider Slayer',),
#  (b'The Sting of the Scorpion',),
#  (b'The Wedding',),
#  (b'Flash Memory',),
#  (b'Head Over Heels',),
#  (b'Heroes and Villains',),
#  (b'Keeping Secrets',),
#  (b'Law of the Jungle',),
#  (b'Mind Games: Part 1',),
#  (b'Mind Games: Part 2',),
#  (b'Royal Scam',),
#  (b'Spider-Man Dis-Abled',),
#  (b'Sword of Shikata',),
#  (b'The Party',),
#  (b'Tight Squeeze',),
#  (b'When Sparks Fly',),
#  (b'Enter the Hunter!',),
#  (b'The Amazing Spider-Man',),
#  (b'The Spectacular Spider-Man',),
#  (b'Watch Movie Free Online',),
#  (b'Marvel 616',),
#  (b'Spider-Man: Identity',),
#  (b'Survival of the Fittest',),
#  (b'The Origin of Spider-Man',),
#  (b'Spider-Man vs Mysterio: Far From Home',),
#  (b'The Spider-Man 2',),
#  (b'Spider-Man: No Way Home',),
#  (b'Brand New Day',),
#  (b'The Cellar',),
#  (b'GHETTO SPIDER-MAN!',),
#  (b'The Road to Goblin War',),
#  (b'Goblin War Part One',),
#  (b'Goblin War Part Two',),
#  (b'Goblin War Part Three',),
#  (b'Goblin War Part Four',),
#  (b"Marvel's Spider-Man",),
#  (b'Japanese Spider-Man',),
#  (b"Spider-Man Forgets About Aunt May's Milk",),
#  (b'Interactions',),
#  (b'The Amazing Spider-Man 2',),
#  (b'Natural Selection',),
#  (b'Market Forces',),
#  (b'Competition',),
#  (b'The Invisible Hand',),
#  (b'Catalysts',),
#  (b'Reaction',),
#  (b'Web of Venom',),
#  (b'Group Therapy',),
#  (b'Persona',),
#  (b'The Uncertainty Principle',),
#  (b'Amazing Friends',),
#  (b'Intervention',),
#  (b'Nature vs. Nurture',),
#  (b'Vengeance of Venom',),
#  (b'Spider-Man 4 Fan Film',),
#  (b'Spider-Man Unmasked',),
#  (b'Generations',),
#  (b'Maximum Venom',),
#  (b'Spider-Man: Excelsior in Purgatory',),
#  (b'Blueprints',),
#  (b'Destructive Testing',),
#  (b'Reinforcement',),
#  (b'Shear Strength',),
#  (b'First Steps',),
#  (b'The Spider-Man Team-Up!',),
#  (b'The Lego Batman, Spider-Man, & Chewbacca Movie',),
#  (b'The Robin',),
#  (b'The Lego Batman & Spider-Man Movie',),
#  (b'The Lego Batman & Spider-Man Movie 2',),
#  (b'The Lego Batman, Spider-Man, & Superman Movie',),
#  (b'Growing Pains',),
#  (b'Identity Crisis',),
#  (b'Avengers: Infinity War Demastered',),
#  (b'Accomplices',),
#  (b'Gangland',),
#  (b'Probable Cause',),
#  (b'Subtext',),
#  (b'Opening Night',),
#  (b'Final Curtain',),
#  (b'SPIDER-MAN PRANK IN REAL LIFE ON FRIENDS!!',),
#  (b'She Caught Me Kissing Her Best Friend',),
#  (b'Fear and Loathing in Vegas Stakes',),
#  (b'The Amazing Spider-Man 2 (2014)',),
#  (b'The LJN Library',),
#  (b'Spider-Woman, Agent of S.W.O.R.D.',),
#  (b'Ultimate Spider-Man',),
#  (b'Episode #1.1',),
#  (b'I Love You, Iron Man/Ben 10 Franklin',),
#  (b'Major League of Extraordinary Gentlemen',),
#  (b'Great Power',),
#  (b'Great Responsibility',),
#  (b'Doomed',),
#  (b'Venom',),
#  (b'Flight of the Iron Spider',),
#  (b'Why I Hate the Gym',),
#  (b'Top 11 Dumbasses in Distress',),
#  (b'Venomous',),
#  (b'Strange',),
#  (b'Freaky',),
#  (b'If Superheroes Were Real',),
#  (b'Exclusive',),
#  (b'Back in Black',),
#  (b'Me Time',),
#  (b'Field Trip',),
#  (b'For Your Eye Only',),
#  (b'Beetle Mania',),
#  (b'Snow Day',),
#  (b'Damage',),
#  (b'Home Sick Hulk',),
#  (b'Run Pig Run',),
#  (b'I Am Spider-Man',),
#  (b'The Iron Octopus',),
#  (b'Not a Toy',),
#  (b'Attack of the Beetle',),
#  (b'Revealed',),
#  (b'Rise of the Goblin',),
#  (b'How Spider-Man 3 Should Have Ended',),
#  (b'New Avengers',),
#  (b'The Lizard',),
#  (b'How Iron Man Should Have Ended',),
#  (b'Awesome',),
#  (b'Spider-Man: Homecoming',),
#  (b'iChronicle/Hulk Smash',),
#  (b'Electro',),
#  (b"Hi, I'm a Marvel... and I'm a DC",),
#  (b'The Rhino',),
#  (b'The Amazing Spider-Minaj/Go, Dragon Ball, Go!',),
#  (b'Hawkeye',),
#  (b'Sinister Six',),
#  (b'Spidah-Man',),
#  (b'Carnage',),
#  (b'Journey of the Iron Fist',),
#  (b'House Arrest',),
#  (b'The Man-Wolf',),
#  (b'Marvel Mash-Up',),
#  (b'The Incredible Spider-Hulk',),
#  (b'Game Over',),
#  (b'Second Chance Hero',),
#  (b'Stan by Me',),
#  (b'Swarm',),
#  (b'Itsy Bitsy Spider-Man',),
#  (b'Ultimate Deadpool',),
#  (b'Venom Bomb',),
#  (b'The Parent Trap',),
#  (b'Guardians of the Galaxy',),
#  (b'The Howling Commandos',),
#  (b'Sandman Returns',),
#  (b'Superheroes: A Never-Ending Battle',),
#  (b'The Collector',),
#  (b'The Avenging Spider-Man: Part 1',),
#  (b'The Avenging Spider-Man: Part 2',),
#  (b'Agent Venom',),
#  (b'Cloak and Dagger',),
#  (b'The Next Iron Spider',),
#  (b'The Vulture',),
#  (b'The Savage Spider-Man',),
#  (b'New Warriors',),
#  (b'The Return of the Guardians of the Galaxy',),
#  (b'The Spider-Verse: Part 2',),
#  (b'The Spider-Verse: Part 3',),
#  (b'The Spider-Verse: Part 4',),
#  (b'The Spider-Verse: Part 1',),
#  (b'Return of the Sinister Six',),
#  (b'Ultimate',),
#  (b'Blade',),
#  (b'SHIELD Academy',),
#  (b'Halloween Night at the Museum',),
#  (b'The Venom Within',),
#  (b'Nightmare on Christmas',),
#  (b'Ant-Man',),
#  (b'Attack of the Synthezoids',),
#  (b'The Revenge of Arnim Zola',),
#  (b'Burrito Run',),
#  (b'Contest of the Champions: Part 1',),
#  (b'Contest of the Champions: Part 2',),
#  (b'Contest of the Champions: Part 3',),
#  (b'Contest of the Champions: Part 4',),
#  (b'How the Amazing Spider-Man Should Have Ended',),
#  (b'How the Avengers Should Have Ended',),
#  (b'How the Amazing Spider-Man 2 Should Have Ended',),
#  (b'Rampaging Rhino',),
#  (b'The Avenging Spider-Man',),
#  (b'Spidey, I Blew Up the Dinosaur',),
#  (b'Web of the Spider-Man',),
#  (b'Super Caf\xc3\xa9: And the Reboot Goes To...',),
#  (b'Inhumanity',),
#  (b'Hydra Attacks: Part 1',),
#  (b'Marvel Knights: Spider-Man',),
#  (b'Marvel Zombies vs. Army of Darkness',),
#  (b'The Spectacular Lego Spider-Man',),
#  (b'Spider-Man vs. Darth Maul',),
#  (b'Hydra Attacks: Part 2',),
#  (b'Miles from Home',),
#  (b'Iron Vulture',),
#  (b'Lizards',),
#  (b'Double Agent Venom',),
#  (b'Beached',),
#  (b'Anti-Venom',),
#  (b'Force of Nature',),
#  (b'Spider-Man: Vengeance',),
#  (b'The New Sinister 6: Part 1',),
#  (b'The New Sinister 6: Part 2',),
#  (b'Agent Web',),
#  (b'The Symbiote Saga: Part 1',),
#  (b'The Symbiote Saga: Part 2',),
#  (b'The Symbiote Saga: Part 3',),
#  (b'Return to the Spider-Verse: Part 1',),
#  (b'Return to the Spider-Verse: Part 2',),
#  (b'Return to the Spider-Verse: Part 3',),
#  (b'Return to the Spider-Verse: Part 4',),
#  (b'Strange Little Halloween',),
#  (b'The Spider Slayers: Part 1',),
#  (b'The Spider Slayers: Part 2',),
#  (b'The Spider Slayers: Part 3',),
#  (b'The Moon Knight Before Christmas',),
#  (b'Graduation Day: Part 1',),
#  (b'Graduation Day: Part 2',),
#  (b'Spider-Man: Far from Home',),
#  (b'Marvel Video Comics',),
#  (b'Spider-Man: Balance Act',),
#  (b'Horizon High: Part One',),
#  (b'Once Bitten: A Spider-Man Story',),
#  (b'Horizon High: Part Two',),
#  (b'Origins',),
#  (b'The Amazing Spider-man Movies',),
#  (b'Osborn Academy',),
#  (b'Party Animals',),
#  (b'A Day in the Life',),
#  (b'Symbiotic Relationship',),
#  (b'Sandman',),
#  (b'Stark Expo',),
#  (b"Kraven's Amazing Hunt",),
#  (b'Halloween Moon',),
#  (b'Spider-Man on Ice',),
#  (b'How Spider-Man Homecoming Should Have Ended',),
#  (b'Screwball Live',),
#  (b'Marvel Super Hero Adventures',),
#  (b'The Rise of Doc Ock: Part One',),
#  (b'The Rise of Doc Ock: Part Two',),
#  (b'The Rise of Doc Ock: Part Three',),
#  (b'The Rise of Doc Ock: Part Four',),
#  (b'Spider-Island: Part One',),
#  (b'Spider-Island: Part Two',),
#  (b'Spider-Island: Part Three',),
#  (b'Spider-Island: Part Four',),
#  (b'Spider-Island: Part Five',),
#  (b'The Hobgoblin: Part One',),
#  (b'The Hobgoblin: Part Two',),
#  (b'How I Thwipped My Summer Vacation',),
#  (b"CF Picture's Spider-Man",),
#  (b'The Marvelous Spider-Man 3: Empire of Blood',),
#  (b'Take Two',),
#  (b'The League of Extraordinary Gentlemen',),
#  (b'Between an Ock and a Hard Place',),
#  (b'Rise Above It All',),
#  (b'School of Hard Knocks',),
#  (b"Dead Man's Party",),
#  (b'Venom Returns',),
#  (b'Bring on the Bad Guys: Part One',),
#  (b'How Infinity War Should Have Ended',),
#  (b'Bring on the Bad Guys: Part Two',),
#  (b'Bring on the Bad Guys: Part Three',),
#  (b'Bring on the Bad Guys: Part Four',),
#  (b'Brain Drain',),
#  (b'The Living Brain',),
#  (b'Avengers: Legacy',),
#  (b'Vibranium Curtain: Part Two',),
#  (b'The Ultimate LEGO Spider-Man (BMCU)',),
#  (b"CF Picture's Spider-Man: Dissension",),
#  (b'How Spider-Man Into the Spider-Verse Should Have Ended',)]

# %% [markdown]
# #### 3 - List and count the 10 people who appeared the most in movies by "Wes Anderson"

# %% [markdown]
# ### Is the IMDB only about movies?
#
# 1. Check the number of different media types contained in the DB
# 2. Plot an histogram about the number of media types per group
# 3. Find the name and rating of the oldest videogame stored in the DB

# %% [markdown]
# #### 1 - Check the number of different media types contained in the DB

# %% [markdown]
# #### 2 - Plot an histogram about the number of media types per group

# %% [markdown]
# #### 3 - Find the name and rating of the oldest videogame stored in the DB

# %% [markdown]
# ### Identify interesting outliers
#
# 1. List the names of movies whose title begin with "The" have a runtime between 3 and 4 hours.
# 2. What actor had the most roles as 'Self'?
# 3. Identify what TV series had more than 1,000 episodes, and check the first- and last-episod year

# %% [markdown]
# #### 1 - List the names of movies whose title begin with "The" have a runtime between 3 and 4 hours.

# %% [markdown]
# #### 2 - What actor had the most roles as 'Self'?

# %% [markdown]
# #### 3 - Identify what TV series had more than 1,000 episodes, and check the first- and last-episod year

# %% [markdown]
# ### It's all about the ratings
#
# 1. Group all movies by decade and plot the rating distribution. Limit the query to the movies with at least 1000 ratings.
# 2. Plot the average rating of each episode of Games of Thrones. Group by season and compute the average and std for each season
# 3. Plot the total numer of movies per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %% [markdown]
# #### 1 - Group all movies by decade and plot the rating distribution. Limit the query to the movies with at least 1000 ratings.

# %% [markdown]
# #### 2 - Plot the average rating of each episode of Games of Thrones. Group by season and compute the average and std for each season

# %% [markdown]
# #### 3 - Plot the total numer of movies per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre
